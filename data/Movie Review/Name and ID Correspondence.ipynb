# %%
import json
import pandas as pd

# %%
with open("cornell_movie_info.json", "r") as read_file:
    data = json.load(read_file)

# %%
movie_ID_and_title = {}

# %%
movie_name_list = list(data.keys())

# %%
len(movie_name_list)
# Out:
# 590

# %%
movie_name_list
# Out:
# ['m0',
#  'm1',
#  'm2',
#  'm3',
#  'm4',
#  'm5',
#  'm6',
#  'm7',
#  'm9',
#  'm10',
#  'm11',
#  'm12',
#  'm13',
#  'm14',
#  'm15',
#  'm16',
#  'm17',
#  'm18',
#  'm19',
#  'm20',
#  'm21',
#  'm22',
#  'm24',
#  'm25',
#  'm26',
#  'm27',
#  'm28',
#  'm29',
#  'm30',
#  'm31',
#  'm32',
#  'm33',
#  'm34',
#  'm35',
#  'm36',
#  'm37',
#  'm38',
#  'm39',
#  'm40',
#  'm41',
#  'm42',
#  'm43',
#  'm44',
#  'm45',
#  'm46',
#  'm47',
#  'm48',
#  'm49',
#  'm50',
#  'm51',
#  'm52',
#  'm53',
#  'm54',
#  'm55',
#  'm56',
#  'm57',
#  'm58',
#  'm59',
#  'm60',
#  'm61',
#  'm62',
#  'm63',
#  'm65',
#  'm66',
#  'm68',
#  'm69',
#  'm70',
#  'm71',
#  'm72',
#  'm73',
#  'm74',
#  'm75',
#  'm76',
#  'm77',
#  'm78',
#  'm79',
#  'm80',
#  'm82',
#  'm83',
#  'm84',
#  'm85',
#  'm86',
#  'm87',
#  'm88',
#  'm89',
#  'm90',
#  'm91',
#  'm92',
#  'm93',
#  'm94',
#  'm95',
#  'm97',
#  'm98',
#  'm99',
#  'm100',
#  'm101',
#  'm102',
#  'm103',
#  'm104',
#  'm105',
# ...

# %%
movie_ID_list = []
movie_title_list = []

# %%
for i in range(len(movie_list)):
    movie_ID_list.append(data[movie_list[i]]['imdbID'])
    movie_title_list.append(data[movie_list[i]]['Title'])

# %%
for i in range(len(movie_list)):
    movie_ID_and_title[movie_ID_list[i]] = movie_title_list[i]

# %%
IMDB_ID_and_name = pd.DataFrame.from_dict(movie_ID_and_title.items())

# %%
IMDB_ID_and_name.to_csv('IMDB_ID_and_name.csv')
